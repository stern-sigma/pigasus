# %%
"""Production script to extract data from each plant of the 50.
data should be a list in dictionaries ready for transformation at the next stage"""
import logging
from requests import get, exceptions

from transform import convert_to_dataframe, parse_botanist_data, parse_origin_location, clean_image_data, clean_scientific_name, format_watered_column, format_recording_taken, capitalise_plant_name, process_temperature_column


logger = logging.getLogger(__name__)  # Create logger for this module
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')
# (The basicConfig line is here for demonstration. In production it may be set elsewhere.)


def get_max_plant_id(base_url: str) -> int:
    """Returns greatest ID predicted by max_plants_on_display."""
    response = get(base_url, timeout=10)
    data = response.json()
    if data and "plants_on_display" in data:
        return data["plants_on_display"]
    raise ValueError("Failed to fetch status information. Status code: %s" %
                     response.status_code)


def extract_plant_batch() -> list[dict]:
    """Returns list of dictionaries for all successful plant get requests."""
    base_url = "https://data-eng-plants-api.herokuapp.com/"
    plant_data_list = []
    max_plant_id = get_max_plant_id(base_url)
    logger.info("Data for %d plants is available...", max_plant_id)
    # Adds 10% leeway to account for missing plants
    max_plant_id += max_plant_id // 10

    for plant_id in range(1, max_plant_id + 1):
        try:
            plant_data = get_plant_data(base_url, plant_id)
            plant_data_list.append(plant_data)
        except ValueError as e:
            logger.error(
                "Error fetching data for plant ID %d: %s", plant_id, e)

    logger.info("Retrieved data for %d plants.", len(plant_data_list))
    return plant_data_list


def get_plant_data(base_url: str, plant_id: int) -> dict:
    """
    Returns data for a specific plant based on its ID number.

    Raises:
        ValueError: If the data for the plant cannot be fetched.
    """
    url = f"{base_url}plants/{plant_id}"
    try:
        response = get(url, timeout=7)
    except exceptions.ReadTimeout as e:
        raise ValueError("Request timed out for plant ID %d: %s" %
                         (plant_id, e)) from e

    if response.status_code == 200:
        plant_data = response.json()
        logger.info("Successfully fetched data for Plant ID %d", plant_id)
        return plant_data

    raise ValueError("Failed to fetch data for plant ID %d. Status code: %d" %
                     (plant_id, response.status_code))


def transform_and_clean_data(raw_data:list[dict]):
    """Returns dataframe that has been cleaned."""
    df = convert_to_dataframe(raw_data)
    df = clean_image_data(df)
    df = clean_scientific_name(df)
    df = format_recording_taken(df)
    df = parse_botanist_data(df)
    df = format_watered_column(df)
    df = parse_origin_location(df)
    df = capitalise_plant_name(df)
    df = process_temperature_column(df)
    return df

if __name__ == "__main__":
    main_data = extract_plant_batch()
    dataframe_sample = (transform_and_clean_data(main_data))
    dataframe_sample.sample()

    logger.info("%s", main_data)
# Out:
# 2025-02-06 15:51:13,865 - INFO - Data for 49 plants is available...
# 2025-02-06 15:51:14,182 - INFO - Successfully fetched data for Plant ID 1
# 2025-02-06 15:51:19,464 - INFO - Successfully fetched data for Plant ID 2
# 2025-02-06 15:51:26,545 - ERROR - Error fetching data for plant ID 3: Request timed out for plant ID 3: HTTPSConnectionPool(host='data-eng-plants-api.herokuapp.com', port=443): Read timed out. (read timeout=7)
# 2025-02-06 15:51:33,621 - ERROR - Error fetching data for plant ID 4: Request timed out for plant ID 4: HTTPSConnectionPool(host='data-eng-plants-api.herokuapp.com', port=443): Read timed out. (read timeout=7)
# 2025-02-06 15:51:38,800 - INFO - Successfully fetched data for Plant ID 5
# 2025-02-06 15:51:45,868 - ERROR - Error fetching data for plant ID 6: Request timed out for plant ID 6: HTTPSConnectionPool(host='data-eng-plants-api.herokuapp.com', port=443): Read timed out. (read timeout=7)
# 2025-02-06 15:51:52,942 - ERROR - Error fetching data for plant ID 7: Request timed out for plant ID 7: HTTPSConnectionPool(host='data-eng-plants-api.herokuapp.com', port=443): Read timed out. (read timeout=7)
# 2025-02-06 15
# 2025-02-06 15:53:05,473 - ERROR - Error fetching data for plant ID 51: Failed to fetch data for plant ID 51. Status code: 404
# 2025-02-06 15:53:05,573 - ERROR - Error fetching data for plant ID 52: Failed to fetch data for plant ID 52. Status code: 404
# 2025-02-06 15:53:05,662 - ERROR - Error fetching data for plant ID 53: Failed to fetch data for plant ID 53. Status code: 404
# 2025-02-06 15:53:05,663 - INFO - Retrieved data for 40 plants.
# /Users/bill_veliz/Documents/group-project-week-1/pigasus/pipeline/transform/transform.py:91: FutureWarning: Parsing 'GMT' as tzlocal (dependent on system timezone) is deprecated and will raise in a future version. Pass the 'tz' keyword or call tz_localize after construction instead
#   df["last_watered"] = pd.to_datetime(
# 2025-02-06 15:53:05,683 - INFO - [{'botanist': {'email': 'gertrude.jekyll@lnhm.co.uk', 'name': 'Gertrude Jekyll', 'phone': '001-481-273-3691x127'}, 'last_watered': 'Thu, 06 Feb 2025 13:54:32 GMT', 'name': 'Venus flytrap', 'origin_location': ['33.95015', '-118.03917', 'South Whittier', 'US', 'America/Los_Angeles'], 'plant_id': 1, 'recording_taken': '2025-02-06 15:51:14', 'soil_moisture': 93.10808052755905, 'temperature': 12.064644399501608}, {'botanist': {'email': 'carl.linnaeus@lnhm.co.uk', 'name': 'Carl Linnaeus', 'phone': '(146)994-1635x35992'}, 'last_watered': 'Thu, 06 Feb 2025 14:10:54 GMT', 'name': 'Corpse flower', 'origin_location': ['7.65649', '4.92235', 'Efon-Alaaye', 'NG', 'Africa/Lagos'], 'plant_id': 2, 'recording_taken': '2025-02-06 15:51:19', 'soil_moisture': 94.51731614649681, 'temperature': 9.218328814233026}, {'botanist': {'email': 'carl.linnaeus@lnhm.co.uk', 'name': 'Carl Linnaeus', 'phone': '(146)994-1635x35992'}, 'images': {'license': 451, 'license_name': 'CC0 1.0 Universal (CC0 1.0) Public Domain Dedication', 'license_url': 'https://creativecommons.org/publicdomain/zero/1.0/', 'medium_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'original_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'regular_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'small_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'thumbnail': 'https://perenual.com/storage/image/upgrade_access.jpg'}, 'last_watered': 'Thu, 06 Feb 2025 14:56:18 GMT', 'name': 'Pitcher plant', 'origin_location': ['22.88783', '84.13864', 'Jashpurnagar', 'IN', 'Asia/Kolkata'], 'plant_id': 5, 'recording_taken': '2025-02-06 15:51:38', 'scientific_name': ['Sarracenia catesbaei'], 'soil_moisture': 96.85827153642384, 'temperature': 11.248668467305572}, {'botanist': {'email': 'eliza.andrews@lnhm.co.uk', 'name': 'Eliza Andrews', 'phone': '(846)669-6651x75948'}, 'images': {'license': 451, 'license_name': 'CC0 1.0 Universal (CC0 1.0) Public Domain Dedication', 'license_url': 'https://creativecommons.org/publicdomain/zero/1.0/', 'medium_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'original_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'regular_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'small_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 'thumbnail': 'https://perenual.com/storage/image/upgrade_access.jpg'}, 'last_watered': 'Thu, 06 Feb 2025 13:23:01 GMT', 'name': 'Bird of paradise', 'origin_location': ['5.27247', '-3.59625', 'Bonoua', 'CI', 'Africa/Abidjan'], 'plant_id': 8, 'recording_taken': '2025-02-06 15:51:53', 'scientific_name': ["Heliconia schiedeana 'Fire and Ice'"], 'soil_moisture': 91.12070277932406, 'temperature': 11.607922063213092}, {'botanist': {'email': 'gertrude.jekyll@lnhm.co.uk', 'name': 'Gertrude Jekyll', 'phone': '001-481-273-3691x127'}, 'images': {'license': 451, 'license_name': 'CC0 1.0 Universal (CC0 1.0) Public Domain Dedication', 'license_url': 'https://creativecommons.org/publicdomain/zero/1.0/', 'medium_url': 'https://perenual.com/storage/image/upgrade_access.jpg', 
# 23                            Aloe Vera            5.0
# 24                       Ficus Elastica            5.0
# 25              Sansevieria Trifasciata          451.0
# 26                   Tacca Integrifolia          451.0
# 27                                  NaN            NaN
# 28                 Saintpaulia Ionantha          451.0
# 29                Gaillardia Aestivalis          451.0
# 30                  Hippeastrum (Group)          451.0
# 31                     Caladium Bicolor            4.0
# 32      Chlorophytum Comosum 'Vittatum'           45.0
# 33               Araucaria Heterophylla            4.0
# 34                  Begonia 'Art Hodes'            NaN
# 35                  Medinilla Magnifica          451.0
# 36            Calliandra Haematocephala            4.0
# 37               Zamioculcas Zamiifolia          451.0
# 38                       Crassula Ovata            4.0
# 39                    Epipremnum Aureum           45.0
#
#                                    image_license_name  \
# 0                                                 NaN
# 1                                                 NaN
# 2   CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 3   CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 4   CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 5                                                 NaN
# 6                                 Attribution License
# 7                                                 NaN
# 8                                                 NaN
# 9                                 Attribution License
# 10                                                NaN
# 11                     Attribution-ShareAlike License
# 12  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 13                                                NaN
# 14  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 15  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 16                     Attribution-ShareAlike License
# 17  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 18                                Attribution License
# 19                                                NaN
# 20                                Attribution License
# 21  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 22                                Attribution License
# 23                     Attribution-ShareAlike License
# 24                     Attribution-ShareAlike License
# 25  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 26  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 27                                                NaN
# 28  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 29  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 30  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 31                                Attribution License
# 32  Attribution-ShareAlike 3.0 Unported (CC BY-SA ...
# 33                                Attribution License
# 34                                                NaN
# 35  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 36                                Attribution License
# 37  CC0 1.0 Universal (CC0 1.0) Public Domain Dedi...
# 38                                Attribution License
# 39  Attribution-ShareAlike 3.0 Unported (CC BY-SA ...
#
#                                     image_license_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2   https://creativecommons.org/publicdomain/zero/...
# 3   https://creativecommons.org/publicdomain/zero/...
# 4   https://creativecommons.org/publicdomain/zero/...
# 5                                                 NaN
# 6        https://creativecommons.org/licenses/by/2.0/
# 7                                                 NaN
# 8                                                 NaN
# 9        https://creativecommons.org/licenses/by/2.0/
# 10                                                NaN
# 11    https://creativecommons.org/licenses/by-sa/2.0/
# 12  https://creativecommons.org/publicdomain/zero/...
# 13                                                NaN
# 14  https://creativecommons.org/publicdomain/zero/...
# 15  https://creativecommons.org/publicdomain/zero/...
# 16    https://creativecommons.org/licenses/by-sa/2.0/
# 17  https://creativecommons.org/publicdomain/zero/...
# 18       https://creativecommons.org/licenses/by/2.0/
# 19                                                NaN
# 20       https://creativecommons.org/licenses/by/2.0/
# 21  https://creativecommons.org/publicdomain/zero/...
# 22       https://creativecommons.org/licenses/by/2.0/
# 23    https://creativecommons.org/licenses/by-sa/2.0/
# 24    https://creativecommons.org/licenses/by-sa/2.0/
# 25  https://creativecommons.org/publicdomain/zero/...
# 26  https://creativecommons.org/publicdomain/zero/...
# 27                                                NaN
# 28  https://creativecommons.org/publicdomain/zero/...
# 29  https://creativecommons.org/publicdomain/zero/...
# 30  https://creativecommons.org/publicdomain/zero/...
# 31       https://creativecommons.org/licenses/by/2.0/
# 32  https://creativecommons.org/licenses/by-sa/3.0...
# 33       https://creativecommons.org/licenses/by/2.0/
# 34                                                NaN
# 35  https://creativecommons.org/publicdomain/zero/...
# 36       https://creativecommons.org/licenses/by/2.0/
# 37  https://creativecommons.org/publicdomain/zero/...
# 38       https://creativecommons.org/licenses/by/2.0/
# 39  https://creativecommons.org/licenses/by-sa/3.0...
#
#                                    image_original_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2   https://perenual.com/storage/image/upgrade_acc...
# 3   https://perenual.com/storage/image/upgrade_acc...
# 4   https://perenual.com/storage/image/upgrade_acc...
# 5                                                 NaN
# 6   https://perenual.com/storage/species_image/100...
# 7                                                 NaN
# 8                                                 NaN
# 9   https://perenual.com/storage/species_image/201...
# 10                                                NaN
# 11  https://perenual.com/storage/species_image/286...
# 12  https://perenual.com/storage/image/upgrade_acc...
# 13                                                NaN
# 14  https://perenual.com/storage/image/upgrade_acc...
# 15  https://perenual.com/storage/image/upgrade_acc...
# 16  https://perenual.com/storage/species_image/855...
# 17  https://perenual.com/storage/image/upgrade_acc...
# 18  https://perenual.com/storage/species_image/288...
# 19                                                NaN
# 20  https://perenual.com/storage/species_image/246...
# 21  https://perenual.com/storage/image/upgrade_acc...
# 22  https://perenual.com/storage/species_image/199...
# 23  https://perenual.com/storage/species_image/728...
# 24  https://perenual.com/storage/species_image/296...
# 25  https://perenual.com/storage/image/upgrade_acc...
# 26  https://perenual.com/storage/image/upgrade_acc...
# 27                                                NaN
# 28  https://perenual.com/storage/image/upgrade_acc...
# 29  https://perenual.com/storage/image/upgrade_acc...
# 30  https://perenual.com/storage/image/upgrade_acc...
# 31  https://perenual.com/storage/species_image/145...
# 32  https://perenual.com/storage/species_image/184...
# 33  https://perenual.com/storage/species_image/917...
# 34                                                NaN
# 35  https://perenual.com/storage/image/upgrade_acc...
# 36  https://perenual.com/storage/species_image/147...
# 37  https://perenual.com/storage/image/upgrade_acc...
# 38  https://perenual.com/storage/species_image/219...
# 39  https://perenual.com/storage/species_image/277...
#
#                 botanist_email    botanist_name        botanist_phone  \
# 0   gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 1     carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 2     carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 3     eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 4   gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 5   gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 6   gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 7     eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 8     eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 9   gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 10  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 11  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 12    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 13    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 14  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 15    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 16    eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 17  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 18    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 19  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 20    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 21    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 22    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 23  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 24    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 25  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 26  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 27    eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 28  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 29    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 30    eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 31    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 32    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 33  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 34  gertrude.jekyll@lnhm.co.uk  Gertrude Jekyll  001-481-273-3691x127
# 35    eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 36    eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 37    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
# 38    eliza.andrews@lnhm.co.uk    Eliza Andrews   (846)669-6651x75948
# 39    carl.linnaeus@lnhm.co.uk    Carl Linnaeus   (146)994-1635x35992
#
#                 region country
# 0       South Whittier      US
# 1          Efon-Alaaye      NG
# 2         Jashpurnagar      IN
# 3               Bonoua      CI
# 4               Weimar      DE
# 5                Split      HR
# 6              Kahului      US
# 7             Longview      US
# 8             Bensheim      DE
# 9          Gainesville      US
# 10             Siliana      TN
# 11             Yonkers      US
# 12              Wangon      ID
# 13             Oschatz      DE
# 14              Tonota      BW
# 15                Reus      ES
# 16      Carlos Barbosa      BR
# 17           Friedberg      DE
# 18           Motomachi      JP
# 19          Ar Ruseris      SD
# 20            El Achir      DZ
# 21             Hlukhiv      UA
# 22           Brunswick      US
# 23     Ueno-ebisumachi      JP
# 24            Ajdabiya      LY
# 25             Licheng      CN
# 26              Dublin      US
# 27              Malaut      IN
# 28            Magomeni      TZ
# 29             Fujioka      JP
# 30             Valence      FR
# 31              Pujali      IN
# 32             Smolyan      BG
# 33  Zacoalco de Torres      MX
# 34      South Whittier      US
# 35              Salima      MW
# 36             Catania      IT
# 37             Calauan      PH
# 38            Acayucan      MX
# 39          Resplendor      BR
